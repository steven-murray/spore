# %%
from pygsm import GlobalSkyModel2016
import numpy as np

# %%
gsm = GlobalSkyModel2016(resolution='low')

# %%
nu = np.linspace(150,160,20)

# %%
# %timeit gsm.generate(nu)
# Out:
# 1 loop, best of 3: 17.8 s per loop

# %%
gsm.map_ni.shape
# Out:
# (6, 49152)

# %%
gsm.generate(150.)
gsm.view()

# %%
gsm.map_ni_hr.shape
# Out:
# (6, 12582912)

# %%
a = np.random.normal(size=(1000,1000))

# %%
# %%timeit 

for i in range(1000):
    a[i,:] += 1
# Out:
# The slowest run took 6.07 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 3: 1.27 ms per loop

# %%
# %%timeit 

for j in range(1000):
    a[:,j] += 1
# Out:
# 100 loops, best of 3: 2.42 ms per loop

# %%
a = np.random.normal(size=(5,4))
a[1:,None].shape
# Out:
# (4, 1, 4)

# %%
a[1:].shape
# Out:
# (4, 4)

# %%
gsm.map_ni_hr.shape
# Out:
# (6, 12582912)
